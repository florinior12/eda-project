# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# * Col1   pelvic_incidence
# * Col2   pelvic tilt
# * Col3   lumbar_lordosis_angle
# * Col4   sacral_slope
# * Col5   pelvic_radius
# * Col6   degree_spondylolisthesis
# * Col7   pelvic_slope
# * Col8   Direct_tilt
# * Col9   thoracic_slope
# * Col10   cervical_tilt
# * Col11   sacrum_angle
# * Col12   scoliosis_slope

# %%
dataset_name = "Dataset_spine.csv"
dataset = pd.read_csv(dataset_name)
dataset.drop(columns=['Unnamed: 13'], inplace=True)
dataset
# Out:
#      pelvic_incidence   pelvic_tilt   lumbar_lordosis_angle   sacral_slope  \
# 0           63.027818     22.552586               39.609117      40.475232
# 1           39.056951     10.060991               25.015378      28.995960
# 2           68.832021     22.218482               50.092194      46.613539
# 3           69.297008     24.652878               44.311238      44.644130
# 4           49.712859      9.652075               28.317406      40.060784
# ..                ...           ...                     ...            ...
# 305         47.903565     13.616688               36.000000      34.286877
# 306         53.936748     20.721496               29.220534      33.215251
# 307         61.446597     22.694968               46.170347      38.751628
# 308         45.252792      8.693157               41.583126      36.559635
# 309         33.841641      5.073991               36.641233      28.767649
#
# ...

# %%
labels_check = dataset.apply(lambda x: True if x['class'] == 'Normal' else False , axis=1)
normal_rows = len(labels_check[labels_check == True].index)
abnormal_rows = len(labels_check[labels_check == False].index)

# %%
print(dataset.shape[0])
print(normal_rows)
print(abnormal_rows)
# Out:
# 310
# 100
# 210

# %%
Y = dataset.pop('class')
labelencoder = LabelEncoder()
Y = labelencoder.fit_transform(Y)

# %%
scaler = StandardScaler()
sc_new_x = scaler.fit_transform(new_x)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
colors = ['tab:blue', 'tab:orange']
pca = TSNE(n_components=2)
x_r = pca.fit_transform(sc_good_d)
plt.figure()
plt.grid()
for ix, iy in zip(x_r, Y):
    plt.plot(ix[0], ix[1], c=colors[iy], marker='o')
plt.show()

# %%
plt.plot(1,2, c='red', marker='o')

# %%
plt.figure()
dataset.hist(figsize=(15,12),bins = 20, color="#007959AA")
plt.show()

# %%
sns.heatmap(dataset.corr())

# %%
dataset['pelvic_incidence']

# %%
x.columns[[0]]
# Out:
# Index(['pelvic_incidence'], dtype='object')

# %%
new_x = x.drop(x.columns[[0]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.539
# Model:                            OLS   Adj. R-squared (uncentered):              0.522
# Method:                 Least Squares   F-statistic:                              31.74
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    4.77e-44
# Time:                        22:50:04   Log-Likelihood:                         -144.60
# No. Observations:                 310   AIC:                                      311.2
# Df Residuals:                     299   BIC:                                      352.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[9]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.539
# Model:                            OLS   Adj. R-squared (uncentered):              0.523
# Method:                 Least Squares   F-statistic:                              35.02
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    7.93e-45
# Time:                        22:50:04   Log-Likelihood:                         -144.61
# No. Observations:                 310   AIC:                                      309.2
# Df Residuals:                     300   BIC:                                      346.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[9]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.539
# Model:                            OLS   Adj. R-squared (uncentered):              0.525
# Method:                 Least Squares   F-statistic:                              39.03
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    1.27e-45
# Time:                        22:50:16   Log-Likelihood:                         -144.64
# No. Observations:                 310   AIC:                                      307.3
# Df Residuals:                     301   BIC:                                      340.9
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[7]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.537
# Model:                            OLS   Adj. R-squared (uncentered):              0.525
# Method:                 Least Squares   F-statistic:                              43.87
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    2.55e-46
# Time:                        22:50:35   Log-Likelihood:                         -144.98
# No. Observations:                 310   AIC:                                      306.0
# Df Residuals:                     302   BIC:                                      335.9
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[5]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.536
# Model:                            OLS   Adj. R-squared (uncentered):              0.526
# Method:                 Least Squares   F-statistic:                              50.10
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    4.83e-47
# Time:                        22:50:52   Log-Likelihood:                         -145.33
# No. Observations:                 310   AIC:                                      304.7
# Df Residuals:                     303   BIC:                                      330.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[5]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.535
# Model:                            OLS   Adj. R-squared (uncentered):              0.526
# Method:                 Least Squares   F-statistic:                              58.36
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    8.83e-48
# Time:                        22:51:03   Log-Likelihood:                         -145.72
# No. Observations:                 310   AIC:                                      303.4
# Df Residuals:                     304   BIC:                                      325.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[2]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.533
# Model:                            OLS   Adj. R-squared (uncentered):              0.525
# Method:                 Least Squares   F-statistic:                              69.52
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    2.35e-48
# Time:                        22:51:18   Log-Likelihood:                         -146.60
# No. Observations:                 310   AIC:                                      303.2
# Df Residuals:                     305   BIC:                                      321.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
new_x = new_x.drop(new_x.columns[[1]], axis=1) 
regressor_OLS = sm.OLS(Y, new_x.values).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.531
# Model:                            OLS   Adj. R-squared (uncentered):              0.525
# Method:                 Least Squares   F-statistic:                              86.64
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):                    3.91e-49
# Time:                        22:51:31   Log-Likelihood:                         -147.12
# No. Observations:                 310   AIC:                                      302.2
# Df Residuals:                     306   BIC:                                      317.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# def backwardElimination(x, Y, sl, columns):
#     numVars = len(x[0])
#     for i in range(0, numVars):
#         regressor_OLS = sm.OLS(Y, x).fit()
#         maxVar = max(regressor_OLS.pvalues).astype(float)
#         if maxVar > sl:
#             for j in range(0, numVars - i):
#                 if (regressor_OLS.pvalues[j].astype(float) == maxVar):
#                     x = np.delete(x, j, 1)
#                     columns = np.delete(columns, j)
                    
#     regressor_OLS.summary()
#     return x, columns
# SL = 0.05
# data_modeled, selected_columns = backwardElimination(data.iloc[:,1:].values, data.iloc[:,0].values, SL, selected_columns)

# %%
dataset.drop(dataset.columns[[1, 2]], axis=1)

# %%
 good_d = dataset[dataset.columns[[4,5,9]]]
